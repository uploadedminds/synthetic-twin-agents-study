# %% [markdown]
# <h1>Generate and Improve Image Descriptions</h1>
#
# In this notebook we prompt a model to describe our images and then we ask the model to improve descriptions. (a-few-shots prompt)
#
# This involves using an image as a scenario of survey questions, and piping the answer to a question into another question.

# %%
from edsl import QuestionFreeText

q1 = QuestionFreeText(
    question_name = "describe",
    question_text = """
    I have an image of an object that I would like you to describe in detail. 
    Based on the image provided, please write a description that includes:

    1. The object's appearance, including color, shape, and material.
    2. Any notable design features or patterns.
    3. The object's functionality or potential use.
    4. The overall impression or aesthetic of the object.
    
    Here is the image: {{ image }}. Please make your description as precise and vivid as possible.
    """
)

# %%
from edsl import QuestionFreeText

q2 = QuestionFreeText(
    question_name = "improvements",
    question_text = """
    Evaluate the description of this image on a scale from 1 to 10.
    Explain the reasoning behind your evaluation.
    Image: {{ image }}
    Description: {{ describe.answer }}
    """
)

# %%
IMAGE_UUIDS = {
    'cabin_luggage': ['4f41ad44-6472-4403-8e59-0fb0e5eca575', 'e30bbefa-b135-4a46-bf32-ed9437be8733', 'a56079a4-1f50-4019-9344-947101bd3e4b'],
    'packing_cubes': ['7c046f64-1209-447d-a68a-b984f3508e0b', '82ffd7a6-87dc-4365-9c9f-2e76263908be', '851dedbe-3b32-45ca-8c32-4ddc510f7327'],
    'water_bottle': ['2a81aec9-c164-4d29-9281-360547f04ac4', 'd34d3ec1-073d-45b9-baca-a0d3411e9e0c', 'ff0ab897-50b8-458e-bfa5-7550b8a48648']
}

# %%
# %%time

from edsl import Scenario, ScenarioList, FileStore

def prefetch_images(image_uuids):
    return {
        product: {
            index: FileStore.pull(uuid) for index, uuid in enumerate(uuids)
        }
        for product, uuids in image_uuids.items()
    }

pre_fetched_images = prefetch_images(IMAGE_UUIDS)

sl = ScenarioList([
    Scenario({
        "question_name": f"{product}_{i + 1}",
        "image": pre_fetched_images[product][i]
    })
    for product in IMAGE_UUIDS
    for i in range(3)
])

sl
# Out:
# CPU times: user 315 ms, sys: 294 ms, total: 610 ms
# Wall time: 19.9 s
# ScenarioList([Scenario({'question_name': 'cabin_luggage_1', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...TkSuQmCC', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'cabin_luggage_2', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...rkJggg==', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'cabin_luggage_3', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...TkSuQmCC', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'packing_cubes_1', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...rkJggg==', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'packing_cubes_2', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...RK5CYII=', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'packing_cubes_3', 'image': FileStore(path='../data...hite.png', base64_string='iVBORw0...rkJggg==', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'water_bottle_1', 'image': FileStore(path='../data...le_1.png', base64_string='UklGRrw...AAAAAAA=', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'water_bottle_2', 'image': FileStore(path='../data...le_2.png', base64_string='UklGRvo...AAAAAAA=', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)}), Scenario({'question_name': 'water_bottle_3', 'image': FileStore(path='../data...le_3.png', base64_string='UklGRmY...dJlAAA==', binary=True, suffix='png', mime_type='image/png', external_locations={}, extracted_text=None)})])

# %%
# %%time

from edsl import Survey

survey = Survey(questions = [q1, q2])
# Out:
# CPU times: user 173 μs, sys: 7 μs, total: 180 μs
# Wall time: 182 μs

# %%
from edsl import Model

Model.services()
# Out:
# PrettyList([['anthropic'],
#             ['azure'],
#             ['bedrock'],
#             ['deep_infra'],
#             ['deepseek'],
#             ['google'],
#             ['groq'],
#             ['mistral'],
#             ['ollama'],
#             ['openai'],
#             ['openai_v2'],
#             ['perplexity'],
#             ['together'],
#             ['xai']])

# %%
# %%time

from edsl import Model, ModelList

ml = ModelList([
  Model("gpt-4o", service_name = "openai", temperature = 0, max_tokens = 5000),
  Model("gemini-1.5-flash", service_name = "google", temperature = 0, maxOutputTokens = 5000)
])

ml
# Out:
# CPU times: user 1.51 ms, sys: 1.86 ms, total: 3.37 ms
# Wall time: 2.07 ms
# ModelList([Model(model_name = 'gpt-4o', service_name = 'openai', temperature = 0, max_tokens = 5000, top_p = 1, frequency_penalty = 0, presence_penalty = 0, logprobs = False, top_logprobs = 3), Model(model_name = 'gemini-1.5-flash', service_name = 'google', temperature = 0, topP = 1, topK = 1, maxOutputTokens = 5000, stopSequences = [])])

# %%
# import os
from dotenv import load_dotenv

load_dotenv()  # By default, loads from .env in the current directory

# Test if the API keys are loaded
# print(os.getenv("OPENAI_API_KEY"))
# print(os.getenv("GOOGLE_API_KEY"))
# print(os.getenv("EXPECTED_PARROT_API_KEY"))
# Out:
# True

# %%
# %%time

results = survey.by(sl).by(ml).run()
# Out:
# CPU times: user 1.99 s, sys: 279 ms, total: 2.27 s
# Wall time: 25.5 s

# %%
results.select('model', 'scenario.question_name', 'answer.*')
# Out:
# Dataset([{'model.model': ['gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash', 'gpt-4o', 'gemini-1.5-flash']}, {'scenario.question_name': ['cabin_luggage_1', 'cabin_luggage_1', 'cabin_luggage_2', 'cabin_luggage_2', 'cabin_luggage_3', 'cabin_luggage_3', 'packing_cubes_1', 'packing_cubes_1', 'packing_cubes_2', 'packing_cubes_2', 'packing_cubes_3', 'packing_cubes_3', 'water_bottle_1', 'water_bottle_1', 'water_bottle_2', 'water_bottle_2', 'water_bottle_3', 'water_bottle_3']}, {'answer.improvements': ['I would rate the description a 9 out of 10.\n\n**Reasoning:**\n\n1. **Accuracy**: The description accurately captures the key features of the suitcase, such as its metallic silver color, rectangular shape with rounded edges, and vertical grooves. These details are clearly visible in the image.\n\n2. **Detail**: It provides a comprehensive overview, covering appearance, design features, and functionality. The mention of reinforced corners, multi-directional wheels, and a retractable handle adds depth to the description.\n\n3. **Clarity**: The language is clear and easy to understand, making it accessible to a wide audience.\n\n4. **Overall Impression**: The description effectively conveys the luxury and durability of the suitcase, aligning with the visual impression from the image.\n\n5. **Minor Improvement**: While the description is thorough, it could include more specific details about the interior features or dimensions for a perfect score.\n\nOverall, the description is well-crafted and aligns closely with the visual elements of the image.', 'I would rate the description of the Rimowa Essential Cabin suitcase a 9 out of 10.\n\n**Reasons for the high score:**\n\n* **Accuracy:** The description is highly accurate in its depiction of the suitcase\'s appearance, design features, and functionality.  It correctly identifies the material (aluminum), color (light brushed silver), and key design elements like the grooved pattern, recessed nameplate, and wheels.  The description of the aesthetic as "modern, understated elegance" is also spot on.\n\n* **Detail:** The level of detail is excellent.  The writer doesn\'t just state facts; they describe the *texture* of the aluminum, the *subtlety* of the grooves and logo, and the overall *feeling* of the suitcase.  This creates a vivid image in the reader\'s mind.\n\n* **Structure:** The description is well-structured, logically progressing from appearance to design features to functionality and finally to aesthetic. This makes it easy to follow and understand.\n\n* **Vocabulary:** The vocabulary is sophisticated and appropriate for the subject matter. Words like "minimalist," "recessed," "embossed," and "ostentation" elevate the description beyond a simple listing of features.\n\n\n**Reason for not giving a perfect 10:**\n\n* **Minor Omission:** While the description is thorough, it could benefit from mentioning the handle\'s extendable nature (if it is extendable) and the presence of any TSA-approved locks. These are important functional aspects of a suitcase.  Adding these details would make the description even more complete.\n\nIn summary, the description is exceptionally well-written and provides a comprehensive and engaging account of the Rimowa suitcase. The minor omission is easily rectified, making it a near-perfect description.', "I would rate the description a 9 out of 10.\n\n**Reasoning:**\n\n1. **Accuracy**: The description accurately captures the key features of the suitcase, such as its sleek, metallic appearance, vertical ridges, telescopic handle, side handle, and multi-directional wheels. These elements are clearly visible in the image.\n\n2. **Detail**: It provides a detailed account of the suitcase's design and functionality, including the material (likely aluminum), TSA-approved locks, and ...
