# %% [markdown]
# <h3>Format Gemini 2.0 Flash Synthetic Twin Agents Survey Responses</h3>

# %%
# # from edsl import Results
# # results = Results.load("../../synthetics_survey_results/gemini_2.0_flash/results_1.json")
# # results.to_pandas().to_csv("../../synthetics_survey_results/gemini_2.0_flash/results_1.csv", index=False)

# import os
# import glob
# from edsl import Results

# INPUT_PATH = "../../synthetics_survey_results/gemini_2.0_flash"
# OUTPUT_PATH = "../../synthetics_survey_results/gemini_2.0_flash"

# # Get all JSON files matching the pattern
# json_files = glob.glob(os.path.join(INPUT_PATH, "results_*.json"))

# for json_file in json_files:
#     # Derive CSV name from JSON name
#     base_name = os.path.basename(json_file).replace(".json", ".csv")
#     csv_file = os.path.join(OUTPUT_PATH, base_name)

#     # Load JSON and convert to CSV
#     results = Results.load(json_file)
#     results.to_pandas().to_csv(csv_file, index=False)

#     print(f"Converted {json_file} -> {csv_file}")

# %%
# import pandas as pd



# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)


# results.head(100)
# Out:
# scenario.question_name  p_1_agree_item_1  p_1_agree_item_2  p_1_agree_item_3  \
# 0                                      4                 4                 3
# 1                                      4                 4                 4
# 2                                      3                 3                 3
# 3                                      4                 4                 4
# 4                                      3                 4                 3
# 5                                      4                 4                 4
# 6                                      4                 4                 4
# 7                                      4                 3                 3
# 8                                      3                 4                 3
# 9                                      4                 4                 4
# 10                                     3                 4                 3
# ...
